# %%
import pandas as pd

df= pd.read_csv("/Users/izx_gamex/Desktop/Tuwaiq/capston/Hdbscan-100/df.csv")
topic =pd.read_csv("/Users/izx_gamex/Desktop/Tuwaiq/capston/Hdbscan-100/topic_model_cvs.csv")

# %%
topic
# Out:
#     Unnamed: 0  Topic  Count                                     Name  \
# 0            0      0   9999                      0_رقم_افضل_او_الطفل
# 1            1      1   7722                     1_اول_بنتي_الله_اللي
# 2            2      2   6499                       2_بنتي_شكرا_شي_انا
# 3            3      3   6005         3_الاطفال_تعاملهم_التعامل_وتعامل
# 4            4      4   4886             4_مرتاحه_التوفيق_وانا_واتمني
# 5            5      5   4732            5_للاطفال_الطفل_بالاطفال_بشكل
# 6            6      6   4653                   6_الله_خير_تبارك_والله
# 7            7      7   4097      7_والمعلمات_راءعات_ومعلمات_المعلمات
# 8            8      8   3872               8_استاذه_المديره_قمه_مديره
# 9            9      9   2978        9_ومتعاونه_والرقي_والحرص_والمديره
# 10          10     10   2401            10_راءعه_حضانه_الحضانه_ممتازه
# 11          11     11   2116       11_ام_حضانه جميله_نظيف_المكان نظيف
# ...

# %%
df
# Out:
#        Unnamed: 0  Comment_ID Time_Elapsed                         Comments  \
# 0               0           1           3m                       مركز ممتاز
# 1               1           1           3m              ومميز بتنوع انشطتهم
# 2               2           1           3m                        الاداريات
# 3               3           1           3m                 والمعلمات بشوشات
# 4               4           1           3m            ويهبل تعاملهم الاطفال
# ...           ...         ...          ...                              ...
# 66788       74409       11201           2y                        بارك الله
# 66789       74410       11202           2y  اشكر موظفات مركز صغاري لتعاونهم
# 66790       74412       11203           1y      ممتاز ماشاء الله تبارك الله
# 66791       74414       11205           2y                        رايع جميل
# 66792       74415       11206           2y                     يردون الهاتف
#
# ...
