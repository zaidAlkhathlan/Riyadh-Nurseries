# %%
import pandas as pd

topic= pd.read_csv("/Users/izx_gamex/Desktop/Tuwaiq/capston/aubmindlab/topic_model_cvs.csv")
df =pd.read_csv("/Users/izx_gamex/Desktop/Tuwaiq/capston/aubmindlab/df.csv")

# %%
topic.tail(55)
# Out:
#      Unnamed: 0  Topic  Count  \
# 48           48     47    213
# 49           49     48    207
# 50           50     49    206
# 51           51     50    206
# 52           52     51    205
# 53           53     52    202
# 54           54     53    199
# 55           55     54    199
# 56           56     55    196
# 57           57     56    195
# 58           58     57    194
# 59           59     58    179
# 60           60     59    173
# 61           61     60    165
# 62           62     61    163
# 63           63     62    160
# 64           64     63    159
# 65           65     64    150
# 66           66     65    149
# 67           67     66    149
# 68           68     67    144
# 69           69     68    143
# 70           70     69    142
# 71           71     70    139
# 72           72     71    138
# 73           73     72    135
# 74           74     73    127
# 75           75     74    127
# 76           76     75    126
# 77           77     76    126
# ...

# %%
df[df["topic"]==101].head(50)
# Out:
#        Unnamed: 0  Comment_ID Time_Elapsed                   Comments  Likes  \
# 68             79           9          10m            والحنان للاطفال    0.0
# 579           650          62           2y              واحتواء للطفل    4.0
# 1438         1614         212           1y             احتواء الاطفال    0.0
# 1607         1811         225           3y              التانيب للطفل    1.0
# 1657         1872         228           1y                امن للاطفال    0.0
# 3481         3926         501           1y               افضل للاطفال    2.0
# 5184         5821         756           1y              واحتواء الطفل    1.0
# 5288         5938         764           2y             والتعليم للطفل    8.0
# 6341         7094         927           1y                وبسيط للطفل   11.0
# 6834         7638        1006           9m               احتواء للطفل    0.0
# 7343         8213        1124           1y            والامان للاطفال    2.0
# ...

# %%
df
# Out:
#        Unnamed: 0  Comment_ID Time_Elapsed                         Comments  \
# 0               0           1           3m                       مركز ممتاز
# 1               1           1           3m              ومميز بتنوع انشطتهم
# 2               2           1           3m                        الاداريات
# 3               3           1           3m                 والمعلمات بشوشات
# 4               4           1           3m            ويهبل تعاملهم الاطفال
# ...           ...         ...          ...                              ...
# 66788       74409       11201           2y                        بارك الله
# 66789       74410       11202           2y  اشكر موظفات مركز صغاري لتعاونهم
# 66790       74412       11203           1y      ممتاز ماشاء الله تبارك الله
# 66791       74414       11205           2y                        رايع جميل
# 66792       74415       11206           2y                     يردون الهاتف
#
# ...
