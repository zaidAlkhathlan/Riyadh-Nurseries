# %%
import pandas as pd

df= pd.read_csv("/Users/izx_gamex/Desktop/Tuwaiq/capston/sentence-transformers/df.csv")
topic =pd.read_csv("/Users/izx_gamex/Desktop/Tuwaiq/capston/sentence-transformers/topic_model_cvs.csv")

# %%
topic.tail(55)
# Out:
#      Unnamed: 0  Topic  Count                                            Name  \
# 84           84     83    167  83_المراكز_افضل المراكز_افضل مركز_اجمل المراكز
# 85           85     84    162                         84_الوقت_طويل_طول_اوقات
# 86           86     85    161           85_للاطفال_بيءه_مناسبه للاطفال_مناسبه
# 87           87     86    159                   86_والمعلمات_بالمعلمات_الكتب_
# 88           88     87    157                                   87_واهتمام___
# 89           89     88    156                    88_فضله_ويرزقكم_رزقهم_عطاءكم
# 90           90     89    152                     89_شكرا_الشكر_مدارس_المدرسه
# 91           91     90    152           90_العربيه_اللغه_الانجليزيه_الانجليزي
# 92           92     91    151                    91_الجميع_الكل_والكل_والجميع
# 93           93     92    151                      92_جديد_قديم_المبني_الجديد
# 94           94     93    150                   93_مرتبه_الفصول_النواحي_تكوين
# ...

# %%
df
# Out:
#        Unnamed: 0  Comment_ID Time_Elapsed                         Comments  \
# 0               0           1           3m                       مركز ممتاز
# 1               1           1           3m              ومميز بتنوع انشطتهم
# 2               2           1           3m                        الاداريات
# 3               3           1           3m                 والمعلمات بشوشات
# 4               4           1           3m            ويهبل تعاملهم الاطفال
# ...           ...         ...          ...                              ...
# 66788       74409       11201           2y                        بارك الله
# 66789       74410       11202           2y  اشكر موظفات مركز صغاري لتعاونهم
# 66790       74412       11203           1y      ممتاز ماشاء الله تبارك الله
# 66791       74414       11205           2y                        رايع جميل
# 66792       74415       11206           2y                     يردون الهاتف
#
# ...
