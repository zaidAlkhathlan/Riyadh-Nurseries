# %%
import pandas as pd

topic= pd.read_csv("/Users/izx_gamex/Desktop/Tuwaiq/capston/bert-base-multilingual-cased/topic_model_cvs.csv")
df =pd.read_csv("/Users/izx_gamex/Desktop/Tuwaiq/capston/bert-base-multilingual-cased/df.csv")

# %%
topic.tail(55)
# Out:
#     Unnamed: 0  Topic  Count                                             Name  \
# 45          45     44    166                 44_قمه_قمه الاخلاق_الاخلاق_الذوق
# 46          46     45    162                          45_واهتمام_حقيقي_تعليم_
# 47          47     46    161            46_والامهات_والاكل_والاسلوب_والاداريه
# 48          48     47    158         47_مدرسه_مدرسه راءعه_الكلمه_مدرسه ممتازه
# 49          49     48    155                     48_للاداره_خاص_للمعلمات_وشكر
# 50          50     49    152                 49_الانشطه_والانشطه_وانشطه_انشطه
# 51          51     50    152                50_والرقي_والحروف_ومتجدده_وخلوقات
# 52          52     51    151                    51_جميله_الروضه_الحضانه_ماشاء
# 53          53     52    150                  52_ومهتمين_مهتمين_يهتمون_بالطفل
# 54          54     53    149                   53_جهودهم_جهودكم_اشكرهم_جهودها
# 55          55     54    143                       54_ام_عبدالله_فيصل_ام خالد
# ...

# %%
df
# Out:
#        Unnamed: 0  Comment_ID Time_Elapsed                         Comments  \
# 0               0           1           3m                       مركز ممتاز
# 1               1           1           3m              ومميز بتنوع انشطتهم
# 2               2           1           3m                        الاداريات
# 3               3           1           3m                 والمعلمات بشوشات
# 4               4           1           3m            ويهبل تعاملهم الاطفال
# ...           ...         ...          ...                              ...
# 66788       74409       11201           2y                        بارك الله
# 66789       74410       11202           2y  اشكر موظفات مركز صغاري لتعاونهم
# 66790       74412       11203           1y      ممتاز ماشاء الله تبارك الله
# 66791       74414       11205           2y                        رايع جميل
# 66792       74415       11206           2y                     يردون الهاتف
#
# ...
